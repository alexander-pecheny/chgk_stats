# %%
import requests

# %%
htmls = []

for i in range(1, 18):
    htmls.append(requests.get("https://rating.chgk.info/tournaments?page={}".format(i)))

# %%
htmls = [req.content for req in htmls]

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(htmls[0], "html.parser")

# %%
rows = soup.find_all("tr")

# %%
[(i, x.get_text().strip()) for i, x in enumerate(rows[252].find_all("td"))]
# Out:
# [(0, '6187'),
#  (1,
#   "X\xa0\n                    \n        \n        \n        \n\n                П'ята октава: Тропік Козерога. Ліга Націй: Україна"),
#  (2, '15.01.20'),
#  (3, 'С'),
#  (4,
#   'Редакторы турнира:\n                                    Кудрявцев Александр Александрович\n                                    Вахрив Тарас Зиновьевич\n\n\n                36'),
#  (5, '{5,2}\n                    \n0,7989\n0,7984\n0,7923'),
#  (6, '41'),
#  (7, '-')]

# %%
def parse_editors(editors):
    sp = editors.split("\n")
    result = [x.strip() for x in sp[1:]]
    empty = result.index("")
    return result[:empty]

# %%
import datetime

def parse_tournament(row):
    tds = [x.get_text().strip() for x in row.find_all("td")]
    editors = parse_editors(tds[4])
    teams = int(tds[6])
    date = datetime.datetime.strptime(tds[2], "%d.%m.%y")
    return (editors, teams, (date.year, date.month))

parse_tournament(rows[250])
# Out:
# (['Донецков Сергей Юрьевич', 'Мальчиков Марк Викторович'], 75, (2020, 1))

# %%
rows[5].get("class")
# Out:
# ['tournament_in_future', '']

# %%
from collections import Counter, defaultdict

by_month = defaultdict(Counter)
all_time = Counter()

for html in htmls:
    soup = BeautifulSoup(html, "html.parser")
    rows = soup.find_all("tr")
    for row in rows:
        if "tournament_in_future" in (row.get("class") or []):
            continue
        try:
            parsed = parse_tournament(row)
        except (IndexError, ValueError):
            continue
        month = parsed[2]
        teams = parsed[1]
        for editor in parsed[0]:
            all_time[editor] += teams
            by_month[month][editor] += teams

# %%
list(enumerate(all_time.most_common(100)))
# Out:
# [(0, ('Мерзляков Максим Петрович', 39325)),
#  (1, ('Терентьев Сергей Александрович', 32375)),
#  (2, ('Островский Владимир Сергеевич', 28842)),
#  (3, ('Кудрявцев Александр Александрович', 25181)),
#  (4, ('Коробейников Александр Геннадьевич', 21884)),
#  (5, ('Науменко Константин Владимирович', 21848)),
#  (6, ('Трефилов Алексей Владиславович', 13739)),
#  (7, ('Моносов Борис Яковлевич', 12757)),
#  (8, ('Матвеев Михаил Леонидович', 12628)),
#  (9, ('Скиренко Андрей Сергеевич', 12591)),
#  (10, ('Саксонов Антон Владимирович', 12259)),
#  (11, ('Полевой Алексей Николаевич', 11533)),
#  (12, ('Иванов Михаил Андреевич', 11078)),
#  (13, ('Лобачёв Сергей Сергеевич', 10745)),
#  (14, ('Шибанов Серафим Александрович', 10665)),
#  (15, ('Богословский Алексей Алексеевич', 10623)),
#  (16, ('Вахрив Тарас Зиновьевич', 10300)),
#  (17, ('Рождествин Александр Олегович', 10294)),
#  (18, ('Подрядчикова Мария Владимировна', 10155)),
#  (19, ('Ершов Павел Михайлович', 9610)),
#  (20, ('Рыбачук Денис Николаевич', 9427)),
#  (21, ('Сахаров Константин Владимирович', 8440)),
#  (22, ('Трефилова Мария Алексеевна', 7879)),
#  (23, ('Коврижных Николай Александрович', 7732)),
#  (24, ('Сушков Владимир Владимирович', 7601)),
#  (25, ('Фарукшин Наиль Евгеньевич', 7582)),
#  (26, ('Мухаметкалиев Анвар Саматович', 7284)),
#  (27, ('Колесов Артём Александрович', 6854)),
#  (28, ('Миротин Евгений Адольфович', 6688)),
#  (29, ('Бороненко Алексей Владимирович', 6629)),
#  (30, ('Гулецкий Артём Владимирович', 6475)),
#  (31, ('Мозуль Максим Леонидович', 6439)),
#  (32, ('Боков Тимофей Александрович', 6135)),
#  (33, ('Шорин Сергей Александрович', 6001)),
#  (34, ('Ерёмин Иван Андреевич', 5929)),
#  (35, ('Абрамов Андрей Леонидович', 5422)),
#  (36, ('Савченков Михаил Владимирович', 5190)),
#  (37, ('Голуб Эдуард Викторович', 5150)),
#  (38, ('Бойко Андрей Андреевич', 5066)),
#  (39, ('Мудрый Александр Васильевич', 4884)),
#  (40, ('Тюнькин Игорь Вячеславович', 4595)),
#  (41, ('Хаиткулов Руслан Гафурович', 4337)),
#  (42, ('Алхазов Григорий Эдуардович', 4152)),
#  (43, ('Солдатов Андрей Владимирович', 4131)),
#  (44, ('Мереминский Станислав Григорьевич', 4038)),
#  (45, ('Разумов Юрий Владимирович', 3987)),
#  (46, ('Карпук Михаил Анатольевич', 3937)),
#  (47, ('Солахян Павел Викторович', 3896)),
#  (48, ('Пономарёв Александр Валентинович', 3773)),
#  (49, ('Мосягин Александр Владимирович', 3592)),
#  (50, ('Ефремов Иван Николаевич', 3570)),
#  (51, ('Мялов Виктор Владимирович', 3560)),
#  (52, ('Руссо Максим Михайлович', 3544)),
#  (53, ('Семушин Иван Николаевич', 3524)),
#  (54, ('Петров Дмитрий Николаевич', 3520)),
#  (55, ('Малкин Михаил Леонидович', 3466)),
#  (56, ('Косарев Ярослав Олегович', 3436)),
#  (57, ('Михеев Олег Сергеевич', 3381)),
#  (58, ('Усков Александр Владимирович', 3381)),
#  (59, ('Брутер Александра Владимировна', 3291)),
#  (60, ('Печеный Александр Павлович', 3284)),
#  (61, ('Екимов Михаил Сергеевич', 3267)),
#  (62, ('Карачун Максим Игоревич', 3221)),
#  (63, ('Белозёров Борис Сергеевич', 3201)),
#  (64, ('Мерзликин Александр Владимирович', 3187)),
#  (65, ('Колмаков Игорь', 3180)),
#  (66, ('Башук Дмитрий Николаевич', 3168)),
#  (67, ('Волосатов Антон Валерьевич', 2909)),
#  (68, ('Яковлева Наталья Витальевна', 2808)),
#  (69, ('Мартыненко Антон Андреевич', 2653)),
#  (70, ('Шевченко Богдан Викторович', 2605)),
#  (71, ('Бреев Виталий Игоревич', 2565)),
#  (72, ('Молдавский Вадим Семёнович', 2528)),
#  (73, ('Маландина Виктория Михайловна', 2503)),
#  (74, ('Борок Дмитрий Владимирович', 2478)),
#  (75, ('Яковлев Вадим Игоревич', 2478)),
#  (76, ('Кукушкин Илья Юрьевич', 2365)),
#  (77, ('Выменец Юрий Яковлевич', 2345)),
#  (78, ('Свинтицкий Дмитрий Фёдорович', 2342)),
#  (79, ('Бабазаде Расул Эльман оглы', 2240)),
#  (80, ('Великов Дмитрий Вадимович', 2219)),
#  (81, ('Чхеидзе Леван Сергеевич', 2218)),
#  (82, ('Спешков Сергей Леонидович', 2189)),
#  (83, ('Демьянцев Игорь Николаевич', 2178)),
#  (84, ('Философов Игорь Юрьевич', 2161)),
#  (85, ('Шагал Ксения Андреевна', 2133)),
#  (86, ('Колышкин Александр Викторович', 2057)),
#  (87, ('Кононенко Евгений Иванович', 1970)),
#  (88, ('Дереза Виктор Николаевич', 1911)),
#  (89, ('Остров Григорий Аронович', 1907)),
#  (90, ('Рожков Артём Юрьевич', 1857)),
#  (91, ('Свешникова Екатерина Владиславовна', 1855)),
#  (92, ('Доцюк Екатерина Владиславовна', 1845)),
#  (93, ('Горелова Наталья Евгеньевна', 1844)),
#  (94, ('Бер Илья Леонидович', 1757)),
#  (95, ('Сидоренков Александр Михайлович', 1743)),
#  (96, ('Либер Александр Витальевич', 1738)),
#  (97, ('Иванов Илья Вячеславович', 1721)),
#  (98, ('Кудряшова Наталья Алексеевна', 1714)),
#  (99, ('Лешкович Евгений Игоревич', 1686))]
